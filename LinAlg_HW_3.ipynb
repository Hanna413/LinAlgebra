# %% [markdown]
# <a href="https://colab.research.google.com/github/Hanna413/LinAlgebra/blob/HomeWork/LinAlg_HW_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Часть 3

# %% [markdown]
# __1.__ Найти собственные векторы и собственные значения для линейного оператора, заданного матрицей
#
# $$A=\begin{pmatrix}
# -1 & -6\\
# 2 & 6
# \end{pmatrix}.$$

# %%
import numpy as np

np.set_printoptions(precision=2, suppress=True)

# %%
a = np.array([[-1, -6], [2, 6]])
w, v = np.linalg.eig(a)
 
print(f'Матрица A:\n{a}')
print(f'Собственные значения:\n{w}')
print(f'Собственные векторы:\n{v}')
# Out:
# Матрица A:
# [[-1 -6]
#  [ 2  6]]
# Собственные значения:
# [2. 3.]
# Собственные векторы:
# [[-0.89  0.83]
#  [ 0.45 -0.55]]

# %% [markdown]
# __2.__ Дан оператор поворота на 180 градусов, задаваемый матрицей
#
# $$A=\begin{pmatrix}
# -1 & 0\\
# 0 & -1
# \end{pmatrix}.$$
#
# Показать, что __любой__ вектор является для него собственным.

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# __3.__ Пусть линейный оператор задан матрицей
#
# $$A=\begin{pmatrix}
# 1 & 1\\
# -1 & 3
# \end{pmatrix}.$$
#
# Установить, является ли вектор $x=(1,1)$ собственным вектором этого линейного оператора.

# %% [markdown]
# ![3.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# **4.** Пусть линейный оператор задан матрицей
#
# $$A=\begin{pmatrix} 0 & 3 & 0\\ 3 & 0 & 0\\ 0 & 0 & 3 \end{pmatrix}.$$
#
# Установить, является ли вектор $x=(3, -3, -4)$ собственным вектором этого линейного оператора.

# %%
A = np.array([[0, 3, 0], [3, 0, 0], [0, 0, 3]])
v, _ = np.linalg.eig(A)
print(v)
# Out:
# [ 3. -3.  3.]

# %% [markdown]
# Должно выполняться равенство
# $$\begin{pmatrix}
# 0 & 3 & 0\\
# 3 & 0 & 0\\
# 0 & 0 & 3
# \end{pmatrix}
# \begin{pmatrix}
# 3\\
# -3\\
# 4
# \end{pmatrix}=
# \lambda
# \begin{pmatrix}
# 3\\
# -3\\
# 4
# \end{pmatrix}
# $$

# %% [markdown]
# Решив систему, получим
# $$\Rightarrow
# \begin{cases}
# 3\lambda=-9\\
# -3\lambda=9\\
# -4\lambda=12
# \end{cases}
# \Rightarrow
# \begin{cases}
# \lambda=-3\\
# \lambda=3
# \end{cases}.$$

# %% [markdown]
# Сістема не имеет смысла, значит вектор не является собственным

# %%
vect = np.array([3, -3, -4])
print(f'A * vect = {A.dot(vect)}')
print(f'lambda1 * vect = {v[0] * vect}')
print(f'lambda2 * vect = {v[1] * vect}')
print(f'lambda3 * vect = {v[2] * vect}')
# Out:
# A * vect = [ -9   9 -12]
# lambda1 * vect = [  9.  -9. -12.]
# lambda2 * vect = [-9.  9. 12.]
# lambda3 * vect = [  9.  -9. -12.]

# %% [markdown]
# Вектор не является собственным.

# %%
b = np.array([[1, 1], [-1, 3]])
v, w = np.linalg.eig(A)
w
# Out:
# array([[ 0.71, -0.71,  0.  ],
#        [ 0.71,  0.71,  0.  ],
#        [ 0.  ,  0.  ,  1.  ]])
